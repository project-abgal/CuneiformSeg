# %%
# %matplotlib inline
import os

from matplotlib import pylab as plt
import numpy as np
from glob import glob
from util import *
from model import *
from tqdm import tqdm_notebook

# %%
#load images
serv = ".."
pathimg = serv+"/data/image/"
pathans = serv+"/data/image red/"
size = 40
resize = 30

img = [cv2.imread(name)[:, :,::-1] for name in sorted(glob(pathimg + "*"))]
ans = [cv2.imread(name)[:, :,::-1] for name in sorted(glob(pathans + "*"))]

# %%
plt.figure(figsize=(15,15))
plt.imshow(img[0])

# %%
plt.figure(figsize=(15,15))
plt.imshow(cv2.bilateralFilter(img[0],9,75,75))
